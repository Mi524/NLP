# %% [markdown]
# ## Language Model

# %%
import os 
import pandas as pd 
import re  
import requests
import matplotlib.pyplot as plt

# %%
file_path = "/Users/tracy/Downloads/下载数据文件/sqlResult_1558435.csv"

df  = pd.read_csv(file_path,encoding='gb18030')
all_articles = df['content'].tolist()

print(all_articles[:10])

def token(string):
    return ' '.join(re.findall('[\w\d]+',string))

a = token('\u3000\u30006月21日，\
    A股纳入MSCI指数尘埃落定，但当天被寄予厚望的券商股并未扛起反弹大旗。22日，在222只纳入MSCI指数的A股股票中，银行股全线飘红，其中招商银行领涨，涨幅达6.66%')

all_articles = [token(str(a)) for a in all_articles[:100]]

text = ''

for a in all_articles:
    text += a
print('length of text: {}'.format(len(text)))

from functools import reduce 

txt_from_reduce = reduce(lambda a1,a2: a1+a2, all_articles[:10])
print(txt_from_reduce)
# Out:
# ['此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/体验版内测，稳定版暂不受影响），以确保工程师可以集中全部精力进行系统优化工作。有人猜测这也是将精力主要用到MIUI 9的研发之中。\r\nMIUI 8去年5月发布，距今已有一年有余，也是时候更新换代了。\r\n当然，关于MIUI 9的确切信息，我们还是等待官方消息。\r\n', '骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考虑性能而去屏蔽掉小核心。相反，他们正联手微软，找到一种适合桌面平台的、兼顾性能和功耗的完美方案。\r\n报道称，微软已经拿到了一些新的源码，以便Windows 10更好地理解big.little架构。\r\n资料显示，骁龙835作为一款集成了CPU、GPU、基带、蓝牙/Wi-Fi的SoC，比传统的Wintel方案可以节省至少30%的PCB空间。\r\n按计划，今年Q4，华硕、惠普、联想将首发骁龙835 Win10电脑，预计均是二合一形态的产品。\r\n当然，高通骁龙只是个开始，未来也许还能见到三星Exynos、联发科、华为麒麟、小米澎湃等进入Windows 10桌面平台。\r\n', '此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n至于电池缩水，可能与刘作虎所说，一加手机5要做市面最轻薄大屏旗舰的设定有关。\r\n按照目前掌握的资料，一加手机5拥有5.5寸1080P三星AMOLED显示屏、6G/8GB RAM，64GB/128GB ROM，双1600万摄像头，备货量“惊喜”。\r\n根据京东泄露的信息，一加5起售价是xx99元，应该是在2799/2899/2999中的某个。\r\n', '这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n', '（原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清晨交警发现有一女子赤裸上身，行走在南坪快速上，期间还起了轻生年头，一辅警发现后赶紧为其披上黄衣，并一路劝说她。\r\n那么事发时\r\n到底都发生了些什么呢？\r\n南都记者带您一起还原现场\r\n南都记者在龙岗大队坂田中队见到了辅警刘青（发现女生的辅警），一位外表高大帅气，说话略
# ...

# %% [markdown]
# ## 正则表达式

# %%
conda install requests
# Out:
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::dask==0.19.1=py37_0
#   - defaults/osx-64::anaconda==5.3.0=py37_0
#   - defaults/osx-64::bottleneck==1.2.1=py37h1d22016_1
#   - defaults/osx-64::h5py==2.8.0=py37h878fce3_3
#   - defaults/osx-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/osx-64::bkcharts==0.2=py37_0
#   - defaults/osx-64::pywavelets==1.0.0=py37h1d22016_0
#   - defaults/osx-64::imageio==2.4.1=py37_0
#   - defaults/osx-64::numba==0.39.0=py37h6440ff4_0
#   - defaults/osx-64::odo==0.5.1=py37_0
#   - defaults/osx-64::pytables==3.4.4=py37h13cba08_0
#   - defaults/osx-64::datashape==0.5.4=py37_1
#   - defaults/osx-64::scikit-image==0.14.0=py37h0a44026_1
#   - defaults/osx-64::bokeh==0.13.0=py37_0
#   - defaults/osx-64::numexpr==2.6.8=py37h1dc9127_0
# ...

# %%
pattern = '\w'

url = 'https://movie.douban.com/'

response = requests.get(url)

#"https://movie.douban.com/subject/27624661/?from=showing"
url_pattern = re.compile('https://movie.douban.com/subject/\d+/\?from=showing')
#https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2549420468.jpg
image_pattern = re.compile("https://img1.doubanio.com/view/photo/s_ratio_poster/public/\w\d+.\w+.jpg")

html_content =  response.text 

image_urls = re.findall(image_pattern,html_content)

urls = url_pattern.findall(html_content)

# %% [markdown]
# ## 关于爬虫的深入知识  beautifulsoup webkit

# %%
for line in html_content.split():
    match = url_pattern.findall(line)
    if match:
        print(match[0])
# Out:
# https://movie.douban.com/subject/27202819/?from=showing
# https://movie.douban.com/subject/27202819/?from=showing
# https://movie.douban.com/subject/27666591/?from=showing
# https://movie.douban.com/subject/27666591/?from=showing
# https://movie.douban.com/subject/2244426/?from=showing
# https://movie.douban.com/subject/2244426/?from=showing
# https://movie.douban.com/subject/30334073/?from=showing
# https://movie.douban.com/subject/30334073/?from=showing
# https://movie.douban.com/subject/27663742/?from=showing
# https://movie.douban.com/subject/27663742/?from=showing
# https://movie.douban.com/subject/26728669/?from=showing
# https://movie.douban.com/subject/26728669/?from=showing
# https://movie.douban.com/subject/27624661/?from=showing
# https://movie.douban.com/subject/27624661/?from=showing
# https://movie.douban.com/subject/25924056/?from=showing
# https://movie.douban.com/subject/25924056/?from=showing
# https://movie.douban.com/subject/30164448/?from=showing
# ...

# %%
import jieba

# %%
ALL_TOKENS = jieba.lcut(text)

valid_tokens = [t for t in ALL_TOKENS if t.strip() and t != 'n']
# print('valid',valid_tokens)

#Get the frequences of words

from collections import Counter 

count = Counter([1, 1, 2, 2, 2, 3, 1, 0])

words_count = Counter(valid_tokens)
most_common = words_count.most_common(10)

# print(most_common)

frequences = [f for w, f in most_common]

x = [i for i in range(len(frequences))]

import matplotlib.pyplot as plt  

plt.plot(x,frequences)
plt.show()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/wy/v0gb2_ds3716l6fjs3x1nvkc0000gn/T/jieba.cache
# Loading model cost 0.637 seconds.
# Prefix dict has been built succesfully.

# %%
import numpy as np 

plt.plot(x,np.log(frequences))

frequences_all = [f for w, f in words_count.most_common()]
frequences_sum = sum(frequences_all)

print(frequences_sum)

def get_prob(word):
    esp = 1 / frequences_sum
    if word in words_count:
        return words_count[word] / frequences_sum
    else:
        return esp
# Out:
# 43931

# %% [markdown]
# ## One-Gram Model

# %%
def product(numbers):
    return reduce(lambda n1,n2:n1 * n2 ,numbers)

def language_model_one_gram(string):
    words = jieba.lcut(string)
    return product([get_prob(w) for w in words])

language_model_one_gram('广交会下个月举行')
# Out:
# 5.897347737106647e-14

# %%
sentences = """
这是一个比较正常的句子
这个一个比较罕见的句子
小明毕业于清华大学
小明毕业于秦华大学
""".split()

for s in sentences:
    print(s,language_model_one_gram(s))
# Out:
# 这是一个比较正常的句子 1.0425690899014913e-19
# 这个一个比较罕见的句子 2.4006525096415913e-20
# 小明毕业于清华大学 3.5439662256633237e-16
# 小明毕业于秦华大学 1.4520814928396766e-20

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "我去吃火锅，今晚 今晚我去吃火锅"
]

for s in need_compared:
    s1,s2 = s.split()
    p1,p2 = language_model_one_gram(s1),language_model_one_gram(s2)

    better =  s1 if p1 > p2 else s2 

    print('{} is more possible'.format(better))
    print('-'*4 + ' {} with probility {}'.format(s1, p1))
    print('-'*4 + ' {} with probility {}'.format(s2, p2))
# Out:
# 明天晚上请你吃大餐，我们一起吃苹果 is more possible
# ---- 今天晚上请你吃大餐，我们一起吃日料 with probility 1.5606231187791591e-43
# ---- 明天晚上请你吃大餐，我们一起吃苹果 with probility 1.6524244787073451e-43
# 真是一只好看的小猫 is more possible
# ---- 真事一只好看的小猫 with probility 2.0333025208709128e-23
# ---- 真是一只好看的小猫 with probility 2.97750043481267e-20
# 今晚我去吃火锅 is more possible
# ---- 我去吃火锅，今晚 with probility 1.9617767643162296e-20
# ---- 今晚我去吃火锅 with probility 8.618281503317629e-16

# %% [markdown]
# ## 2 Gram Model

# %% [markdown]
# Get the combination probability of 2-grams

# %% [markdown]
# $$Pr(w_{2}|w_{1}) = {Pr(w_{1}•w_{2}) \over Pr(w_{1})}$$

# %%
valid_tokens = [ str(t) for t in valid_tokens]

all_2_grams_words = [''.join(valid_tokens[i:i+2]) for i in range(len(valid_tokens[:-2]))]

_2_gram_sum = len(all_2_grams_words)
_2_gram_counter = Counter(all_2_grams_words)

def get_combination_prob(w1, w2):
    if w1 + w2 in _2_gram_counter: return _2_gram_counter[w1+w2] / _2_gram_sum
    else:
        return 1 / _2_gram_sum

get_combination_prob('去','北京')
# Out:
# 2.2764005554417357e-05

# %%
def get_prob_2_gram(w1,w2):
    return get_combination_prob(w1,w2) / get_prob(w1)

get_prob_2_gram('去','沈阳')
# Out:
# 0.03333485093370363

# %%
import icecream as ic

# %%
def language_model_of_2_gram(sentence):
    sentence_probability = 1 
    words = jieba.lcut(sentence)
    
    for i, word in enumerate(words):
        if i ==0 :
            prob = get_prob(word)
        else:
            previous = words[i-1]
            prob = get_prob_2_gram(previous,word)
        sentence_probability *= prob 
    return sentence_probability

language_model_of_2_gram('小明今天抽到一部手机')
# Out:
# 小明
# 小明
# 今天
# 抽到
# 一部
# 1.339242052686381e-06

# %% [markdown]
# ## Review the problem using 2-gram

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "今晚我去吃火锅 今晚火锅去吃我",
    "洋葱奶昔来一杯 养乐多绿来一杯"
]

# %%
for s in need_compared:
    s1,s2 = s.split()
    p1,p2 = language_model_of_2_gram(s1),language_model_of_2_gram(s2)
    
    better = s1 if p1 > p2 else s2
    print('{} is more possible'.format(better))
    print('-'*4 + ' {} with probility {}'.format(s1, p1))
    print('-'*4 + ' {} with probility {}'.format(s2, p2))
# Out:
# 明天晚上请你吃大餐，我们一起吃苹果 is more possible
# ---- 今天晚上请你吃大餐，我们一起吃日料 with probility 2.1090920555964752e-12
# ---- 明天晚上请你吃大餐，我们一起吃苹果 with probility 2.1090920555964752e-12
# 真是一只好看的小猫 is more possible
# ---- 真事一只好看的小猫 with probility 4.673265894320272e-10
# ---- 真是一只好看的小猫 with probility 4.673053139505024e-09
# 今晚火锅去吃我 is more possible
# ---- 今晚我去吃火锅 with probility 7.092236262117792e-09
# ---- 今晚火锅去吃我 with probility 7.589038298556158e-07
# 养乐多绿来一杯 is more possible
# ---- 洋葱奶昔来一杯 with probility 7.11439950043691e-07
# ---- 养乐多绿来一杯 with probility 2.276504195431512e-05
